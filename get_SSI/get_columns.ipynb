# %%
list_chitieu = ['TỔNG TÀI SẢN','TÀI SẢN NGẮN HẠN','Tiền và tương đương tiền','Giá trị thuần đầu tư ngắn hạn','Các khoản phải thu','Hàng tồn kho, ròng','TÀI SẢN DÀI HẠN','Phải thu dài hạn','Tài sản cố định','GTCL TSCĐ hữu hình','Nguyên giá TSCĐ hữu hình','Khấu hao lũy kế TSCĐ hữu hình','GTCL Tài sản thuê tài chính','Nguyên giá tài sản thuê tài chính','Khấu hao lũy kế tài sản thuê tài chính','GTCL tài sản cố định vô hình','Nguyên giá TSCĐ vô hình','Khấu hao lũy kế TSCĐ vô hình','Bất động sản đầu tư','Nguyên giá tài sản đầu tư','Khấu hao lũy kế tài sản đầu tư','Tài sản dở dang dài hạn','Đầu tư dài hạn',
                'NỢ PHẢI TRẢ','Nợ ngắn hạn','Phải trả người bán','Người mua trả tiền trước','Doanh thu chưa thực hiện ngắn hạn','Vay ngắn hạn','Nợ dài hạn','Người mua trả tiền trước dài hạn','Doanh thu chưa thực hiên','Vay dài hạn','Trái phiếu chuyển đổi','VỐN CHỦ SỞ HỮU','Vốn góp','Thặng dư vốn cổ phần','Cổ phiếu Quỹ','Lãi chưa phân phối','Lợi ích cổ đông không kiểm soát','Doanh số thuần','Lãi gộp','Thu nhập tài chính','Chi phí tài chính','Trong đó: Chi phí lãi vay','Lãi/(lỗ) từ công ty liên doanh','Chi phí bán hàng','Chi phí quản lý doanh  nghiệp','Thu nhập khác, ròng','Lãi/(lỗ) ròng trước thuế','Lãi/(lỗ) thuần sau thuế','Lợi nhuận của Cổ đông của Công ty mẹ',
                'Lưu chuyển tiền thuần từ các hoạt động sản xuất kinh doanh','Khấu hao TSCĐ','Chi phí dự phòng','Chi phí lãi vay','Chi phí lãi vay đã trả','Thuế thu nhập doanh nghiệp đã trả','Lưu chuyển tiền tệ ròng từ hoạt động đầu tư','Tiền mua tài sản cố định và các tài sản dài hạn khác','Tiền thu được từ thanh lý tài sản cố định','Cổ tức và tiền lãi nhận được','Lưu chuyển tiền tệ từ hoạt động tài chính','Tiền thu từ phát hành cổ phiếu và vốn góp','Chi trả cho việc mua lại, trả lại cổ phiếu','Tiền thu được các khoản đi vay','Tiển trả các khoản đi vay','Tiền thanh toán vốn gốc đi thuê tài chính','Cổ tức đã trả'
]
def add_ratios_Q(x):
    x = x[list_chitieu]
    x['bs_cash'] = x['Tiền và tương đương tiền'] + x['Giá trị thuần đầu tư ngắn hạn']
    x['bs_ar'] = x['Các khoản phải thu'] + x['Phải thu dài hạn']
    x['bs_fa'] = x['GTCL TSCĐ hữu hình'] + x['GTCL Tài sản thuê tài chính'] + x['GTCL tài sản cố định vô hình'] + x['Bất động sản đầu tư'] + x['Tài sản dở dang dài hạn']
    x['bs_gross_fa'] = x['Nguyên giá TSCĐ hữu hình'] + x['Nguyên giá tài sản thuê tài chính'] + x['Nguyên giá TSCĐ vô hình'] + x['Nguyên giá tài sản đầu tư']
    x['other_asset'] = (x['TỔNG TÀI SẢN'] - x['bs_cash'] - x['bs_ar'] - x['Hàng tồn kho, ròng'] - x['bs_fa'] - x['Tài sản dở dang dài hạn']-x['Đầu tư dài hạn'])
    x['bs_cust_pre'] = x['Doanh thu chưa thực hiện ngắn hạn'] + x['Doanh thu chưa thực hiên'] + x['Người mua trả tiền trước'] + x['Người mua trả tiền trước dài hạn']
    x['debt'] = x['Vay ngắn hạn'] + x['Vay dài hạn'] + x['Trái phiếu chuyển đổi']
    x['other_lia'] = (x['NỢ PHẢI TRẢ'] - x['debt'] - x['Phải trả người bán'] - x['bs_cust_pre'])
    x['other_equity'] = (x['VỐN CHỦ SỞ HỮU'] - x['Vốn góp'] - x['Lãi chưa phân phối'] - x['Cổ phiếu Quỹ'])
    x['netdebt'] = (x['debt'] - x['bs_cash'])
    x['ca/ta'] = x['TÀI SẢN NGẮN HẠN']/x['TỔNG TÀI SẢN']
    x['de'] = x['debt']/x['VỐN CHỦ SỞ HỮU']

    x['tax_rate'] = 1-(x['Lãi/(lỗ) thuần sau thuế']/x['Lãi/(lỗ) ròng trước thuế'])
    x['op'] = (x['Lãi gộp'] + x['Chi phí bán hàng'] + x['Chi phí quản lý doanh  nghiệp'])
    x['core_e'] = x['op'] * (1 - x['tax_rate'])
    x['fin_income'] = x['Thu nhập tài chính'] + (x['Chi phí tài chính'] - x['Trong đó: Chi phí lãi vay'])
    x['EBT'] = x['op'] + x['Trong đó: Chi phí lãi vay']
    
   
    x['cf_div'] = x['Cổ tức đã trả'] + x['Chi trả cho việc mua lại, trả lại cổ phiếu']
    x['cf_delta_debt'] = x['Tiền thu được các khoản đi vay'] + x['Tiển trả các khoản đi vay'] + x['Tiền thanh toán vốn gốc đi thuê tài chính']
    x['cf_dep'] = x['Khấu hao TSCĐ'] + x['Chi phí dự phòng']
    x['cf_khac'] = (x['Lưu chuyển tiền thuần từ các hoạt động sản xuất kinh doanh']+x['Lưu chuyển tiền tệ ròng từ hoạt động đầu tư']+x['Lưu chuyển tiền tệ từ hoạt động tài chính']) - (x['Lãi/(lỗ) thuần sau thuế']+x['cf_dep']+x['Tiền mua tài sản cố định và các tài sản dài hạn khác']+x['Tiền thu từ phát hành cổ phiếu và vốn góp']+x['cf_delta_debt']+x['cf_div'])
    
    x['operating_EBITDA'] = x['op']+x['cf_dep']
    x['EBITDA'] = (x['Lãi/(lỗ) ròng trước thuế']-x['Thu nhập khác, ròng'] + x['cf_dep'] - x['Trong đó: Chi phí lãi vay'])
    x['roe_4Q'] = x['Lãi/(lỗ) thuần sau thuế']/x['VỐN CHỦ SỞ HỮU'].rolling(4, min_periods=4).mean()
    x['roe_core_4Q'] = x['core_e']/x['VỐN CHỦ SỞ HỮU'].rolling(4, min_periods=4).mean()
    x['roa_4Q'] = x['Lãi/(lỗ) thuần sau thuế']/x['TỔNG TÀI SẢN'].rolling(4, min_periods=4).mean()

    return x

# %%
col1 = ['Lãi gộp', 'op', 'EBT', 'Lãi/(lỗ) ròng trước thuế', 'Lãi/(lỗ) thuần sau thuế', 'Lợi nhuận của Cổ đông của Công ty mẹ', 'core_e','EBITDA']
col3 = ['Doanh số thuần', 'Lãi gộp', 'op', 'EBT', 'Lãi/(lỗ) ròng trước thuế', 'Lãi/(lỗ) thuần sau thuế', 'Lợi nhuận của Cổ đông của Công ty mẹ', 'core_e','EBITDA']
col2 = ['Doanh số thuần', 'Lãi gộp', 'op', 'EBT', 'Lãi/(lỗ) ròng trước thuế', 'Lãi/(lỗ) thuần sau thuế', 'Lợi nhuận của Cổ đông của Công ty mẹ', 'core_e','EBITDA', 
        'Doanh số thuần_4Q', 'Lãi gộp_4Q', 'op_4Q','Lãi/(lỗ) ròng trước thuế', 'Lãi/(lỗ) thuần sau thuế_4Q', 'Lợi nhuận của Cổ đông của Công ty mẹ_4Q', 'core_e_4Q','EBITDA_4Q']
def margin_func(x):
    for i in col1:
        x[i + "_m"] = x[i] / x['Doanh số thuần']
    return x

def ttm(x):
    for i in col3:
        x[i + "_4Q"] = x[i].rolling(4, min_periods=4).sum()
    return x

def g_func(x):
    for i in col2:
        x["g_" + i] = x[i].pct_change(periods=3) 
    return x

# %%
def get_fs_Q(ticker):
    bs = financial_report(ticker,'BalanceSheet','Quarterly')
    pl = financial_report(ticker,'IncomeStatement','Quarterly')
    cf = financial_report(ticker,'CashFlow','Quarterly')
    cf = cf.rename(columns={'Unnamed: 0': 'CHỈ TIÊU'})
    fs = pd.concat([bs,pl,cf])
    #delete all the column with NaN value > 40
    fs = fs.dropna(axis=1,thresh=40)
    fs = fs.T
    fs.columns = fs.iloc[0]
    fs = fs.iloc[1:,:]
    fs = add_ratios_Q(fs)
    fs = margin_func(fs)
    fs = ttm(fs)
    fs = g_func(fs)
   
    fs['year'] = fs.index.str[-4:].astype(int)
    fs['quarter'] = fs.index.str[1].astype(float)
    fs['dates'] = pd.PeriodIndex(year=fs["year"], quarter=fs["quarter"])
    fs['dates'] = fs['dates'].dt.to_timestamp(freq='Q')
    return fs

# %%
def get_mc(ticker):
    query1 = """
    IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'##temp4') AND type in (N'U'))
    DROP Table ##temp3
    Select 
    OrganCode
    ,Year(TradingDate) AS YEAR_
    ,DATEPART(QUARTER,TradingDate) AS Quarter_
    ,max(TradingDate) as max_TradingDate
    into ##temp3
    from stx_rto_RatioTTMDaily
    group by OrganCode,Year(TradingDate), DATEPART(QUARTER,TradingDate)
    """
    conn = pyodbc.connect('Driver={SQL Server};'
                          'Server=42.112.22.56;'
                          'Database=SDv2;'
                          'UID=FiinRate.SDv2.View;'
                          'PWD=FiinR@tings1234')
    conn.autocommit=True
    cursor=conn.cursor()
    cursor.execute(query1)
    conn.commit()

    query2 = """
    Select 
    T1.OrganCode, T1.Ticker
    ,TradingDate
    ,T2.YEAR_
    ,T2.Quarter_
    ,RTD11
    from stx_rto_RatioTTMDaily T1
    JOIN ##temp3 T2 ON T1.OrganCode = T2.OrganCode AND T1.TradingDate = T2.max_TradingDate
    where Ticker =\'"""+ ticker+"""\' 
    Order by T1.OrganCode,max_TradingDate
    """
    mc = pd.read_sql_query(query2,conn)
    mc['TradingDate'] = pd.to_datetime(mc['TradingDate'])
    mc['year'] = mc['TradingDate'].dt.year
    mc['quarter'] = mc['TradingDate'].dt.quarter
    mc['year'] = mc['year'].astype(float)
    mc = mc.rename(columns={'RTD11':'mc'})
    mc = mc[mc['mc']!=0]
    mc = pl.from_pandas(mc[['year','quarter','mc']])
    mc = mc.select([pl.col('year').cast(pl.Int32).alias('year'),
                    pl.col('quarter').cast(pl.Float64).alias('quarter'),
                    pl.col('mc')])
    return mc

# %%
def get_data(ticker):
    x = get_fs_Q(ticker)
    x = pl.from_pandas(x)
    y = get_mc(ticker)
    x = pl.concat([y,x],how='align')
    x = x.with_columns((pl.col('mc')/pl.col('Lãi/(lỗ) thuần sau thuế_4Q')).alias('P/E'))
    x = x.with_columns((pl.col('mc')/pl.col('VỐN CHỦ SỞ HỮU')).alias('P/B'))

    return x

# %%
get_data('HPG')
# Out:
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['bs_cash'] = x['Tiền và tương đương tiền'] + x['Giá trị thuần đầu tư ngắn hạn']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['bs_ar'] = x['Các khoản phải thu'] + x['Phải thu dài hạn']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['bs_fa'] = x['GTCL TSCĐ hữu hình'] + x['GTCL Tài sản thuê tài chính'] + x['GTCL tài sản cố định vô hình'] + x['Bất động sản đầu tư'] + x['Tài sản dở dang dài hạn']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['bs_gross_fa'] = x['Nguyên giá TSCĐ hữu hình'] + x['Nguyên giá tài sản thuê tài chính'] + x['Nguyên giá TSCĐ vô hình'] + x['Nguyên giá tài sản đầu tư']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['other_asset'] = (x['TỔNG TÀI SẢN'] - x['bs_cash'] - x['bs_ar'] - x['Hàng tồn kho, ròng'] - x['bs_fa'] - x['Tài sản dở dang dài hạn']-x['Đầu tư dài hạn'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['bs_cust_pre'] = x['Doanh thu chưa thực hiện ngắn hạn'] + x['Doanh thu chưa thực hiên'] + x['Người mua trả tiền trước'] + x['Người mua trả tiền trước dài hạn']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['debt'] = x['Vay ngắn hạn'] + x['Vay dài hạn'] + x['Trái phiếu chuyển đổi']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['other_lia'] = (x['NỢ PHẢI TRẢ'] - x['debt'] - x['Phải trả người bán'] - x['bs_cust_pre'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['other_equity'] = (x['VỐN CHỦ SỞ HỮU'] - x['Vốn góp'] - x['Lãi chưa phân phối'] - x['Cổ phiếu Quỹ'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['netdebt'] = (x['debt'] - x['bs_cash'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['ca/ta'] = x['TÀI SẢN NGẮN HẠN']/x['TỔNG TÀI SẢN']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['de'] = x['debt']/x['VỐN CHỦ SỞ HỮU']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['tax_rate'] = 1-(x['Lãi/(lỗ) thuần sau thuế']/x['Lãi/(lỗ) ròng trước thuế'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['op'] = (x['Lãi gộp'] + x['Chi phí bán hàng'] + x['Chi phí quản lý doanh  nghiệp'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['core_e'] = x['op'] * (1 - x['tax_rate'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['fin_income'] = x['Thu nhập tài chính'] + (x['Chi phí tài chính'] - x['Trong đó: Chi phí lãi vay'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['EBT'] = x['op'] + x['Trong đó: Chi phí lãi vay']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['cf_div'] = x['Cổ tức đã trả'] + x['Chi trả cho việc mua lại, trả lại cổ phiếu']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['cf_delta_debt'] = x['Tiền thu được các khoản đi vay'] + x['Tiển trả các khoản đi vay'] + x['Tiền thanh toán vốn gốc đi thuê tài chính']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['cf_dep'] = x['Khấu hao TSCĐ'] + x['Chi phí dự phòng']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['cf_khac'] = (x['Lưu chuyển tiền thuần từ các hoạt động sản xuất kinh doanh']+x['Lưu chuyển tiền tệ ròng từ hoạt động đầu tư']+x['Lưu chuyển tiền tệ từ hoạt động tài chính']) - (x['Lãi/(lỗ) thuần sau thuế']+x['cf_dep']+x['Tiền mua tài sản cố định và các tài sản dài hạn khác']+x['Tiền thu từ phát hành cổ phiếu và vốn góp']+x['cf_delta_debt']+x['cf_div'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['operating_EBITDA'] = x['op']+x['cf_dep']
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['EBITDA'] = (x['Lãi/(lỗ) ròng trước thuế']-x['Thu nhập khác, ròng'] + x['cf_dep'] - x['Trong đó: Chi phí lãi vay'])
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['roe_4Q'] = x['Lãi/(lỗ) thuần sau thuế']/x['VỐN CHỦ SỞ HỮU'].rolling(4, min_periods=4).mean()
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['roe_core_4Q'] = x['core_e']/x['VỐN CHỦ SỞ HỮU'].rolling(4, min_periods=4).mean()
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\951976520.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['roa_4Q'] = x['Lãi/(lỗ) thuần sau thuế']/x['TỔNG TÀI SẢN'].rolling(4, min_periods=4).mean()
# C:\Users\HP PAVILION\AppData\Local\Temp\ipykernel_25216\296764075.py:36: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   mc = pd.read_sql_query(query2,conn)
# shape: (69, 134)
# ┌──────┬─────────┬───────────┬─────────────┬───┬─────────────┬─────────────┬────────────┬──────────┐
# │ year ┆ quarter ┆ mc        ┆ TỔNG TÀI    ┆ … ┆ g_EBITDA_4Q ┆ dates       ┆ P/E        ┆ P/B      │
# │ ---  ┆ ---     ┆ ---       ┆ SẢN         ┆   ┆ ---         ┆ ---         ┆ ---        ┆ ---      │
# │ i32  ┆ f64     ┆ f64       ┆ ---         ┆   ┆ f64         ┆ datetime[ns ┆ f64        ┆ f64      │
# │      ┆         ┆           ┆ f64         ┆   ┆             ┆ ]           ┆            ┆          │
# ╞══════╪═════════╪═══════════╪═════════════╪═══╪═════════════╪═════════════╪════════════╪══════════╡
# │ 2007 ┆ 1.0     ┆ null      ┆ 2.5115e12   ┆ … ┆ null        ┆ 2007-03-31  ┆ null       ┆ null     │
# │      ┆         ┆           ┆             ┆   ┆             ┆ 00:00:00    ┆            ┆          │
# │ 2007 ┆ 2.0     ┆ null      ┆ 3.6329e12   ┆ … ┆ null        ┆ 2007-06-30  ┆ null       ┆ null     │
# │      ┆         ┆           ┆             ┆   ┆             ┆ 00:00:00    ┆            ┆          │
# │ 2007 ┆ 3.0     ┆ null      ┆ 3.7516e12   ┆ … ┆ null        ┆ 2007-09-30  ┆ null       ┆ null     │
# │      ┆         ┆           ┆             ┆   ┆             ┆ 00:00:00    ┆            ┆          │
# │ 2007 ┆ 4.0     ┆ null      ┆ 4.6850e12   ┆ … ┆ null        ┆ 2007-12-31  ┆ null       ┆ null     │
# │      ┆         ┆           ┆             ┆   ┆             ┆ 00:00:00    ┆            ┆          │
# │ …    ┆ …       ┆ …         ┆ …           ┆ … ┆ …           ┆ …           ┆ …          ┆ …        │
# │ 2023 ┆ 2.0     ┆ 1.5206e14 ┆ 1.7624e14   ┆ … ┆ -0.707514   ┆ 2023-06-30  ┆ -77.841236 ┆ 1.553814 │
# │      ┆         ┆           ┆             ┆   ┆             ┆ 00:00:00    ┆            ┆          │
# │ 2023 ┆ 3.0     ┆ 1.5293e14 ┆ 1.7351e14   ┆ … ┆ -0.410651   ┆ 2023-09-30  ┆ 83.446836  ┆ 1.531353 │
# │      ┆         ┆           ┆             ┆   ┆             ┆ 00:00:00    ┆            ┆          │
# │ 2023 ┆ 4.0     ┆ 1.6252e14 ┆ 1.8778e14   ┆ … ┆ 0.439152    ┆ 2023-12-31  ┆ 23.899115  ┆ 1.580406 │
# │      ┆         ┆           ┆             ┆   ┆             ┆ 00:00:00    ┆            ┆          │
# │ 2024 ┆ 1.0     ┆ 1.6369e14 ┆ null        ┆ … ┆ null        ┆ null        ┆ null       ┆ null     │
# └──────┴─────────┴───────────┴─────────────┴───┴─────────────┴─────────────┴────────────┴──────────┘
